# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f"Added {project_root} to Python path")
# Out:
# Added /Users/diego/Documents/maestriaUTEC/capstone/lympha to Python path

# %%
from experiments.registry import MODEL_REGISTRY
from experiments.trainer import run_experiments

datasets = ["subset_high_density_soft"]
horizons = [24, 48, 96, 192, 336, 720]
models = ["MICN", "LSTM"]

run_experiments(datasets, horizons, models)

print("All experiments completed.")
# Out:
# ⚠️ Model LSTM not found in registry, skipping...
# All experiments completed.
